# %% [markdown]
# # AI for Sustainable Development
# **Theme:** *Machine Learning Meets the UN Sustainable Development Goals (SDGs)* 🌍🤖
#
# ---
#
# ## 📌 Title
# **Using Machine Learning to Predict Malaria Outbreaks: An AI Approach to Achieving SDG 3 (Good Health and Well-being)**
#
# ---
#
# ## 📝 Introduction
# The Sustainable Development Goals (SDGs) set by the United Nations aim to create a better and more sustainable future for all. Among them, **SDG 3 – Good Health and Well-being** seeks to ensure healthy lives and promote well-being for people of all ages.
#
# Malaria remains a significant global health issue, especially in Sub-Saharan Africa. Despite global efforts, it continues to affect millions annually. With the rise of Artificial Intelligence (AI), particularly Machine Learning (ML), we now have tools that can predict and potentially prevent such outbreaks by analyzing historical and environmental data.
#
# This project demonstrates how **supervised learning** can be applied to predict malaria outbreaks, enabling timely response and resource allocation for affected regions.
#
# ---
#
# ## 💡 Project Description
# This project involves building a **supervised machine learning model** that predicts the likelihood of a **malaria outbreak** in a given region using health, environmental, and weather-related data.
#
# We utilize a dataset containing variables such as:
# - Rainfall
# - Temperature
# - Humidity
# - Population density
# - Previous infection rates
#
# The model leverages classification algorithms like **Decision Trees** and **Random Forests** to forecast outbreak risks. The primary goal is to empower health organizations, governments, and NGOs with actionable insights for **early intervention** and **resource prioritization**.
#
# ---
#
# ## ❗ Problem Statement
# Malaria continues to be a life-threatening disease in many low- and middle-income countries. Traditional prevention strategies often suffer from delayed detection and inefficient resource allocation.
#
# There is a clear need for **data-driven predictive models** that can anticipate malaria outbreaks and support early response mechanisms, especially in high-risk regions with constrained healthcare systems.
#
# ---
#
# ## 🎯 Main Objective
# To design and implement a machine learning model that can **predict malaria outbreaks** using relevant features, supporting proactive health interventions in line with **SDG 3 – Good Health and Well-being**.
#
# ---
#
# ## ✅ Specific Objectives
# 1. **Data Acquisition & Preprocessing**
#    - Source open datasets (e.g., WHO, Kaggle) and clean them for modeling.
#
# 2. **Feature Engineering**
#    - Identify and select key variables such as rainfall, temperature, humidity, population density, and historical malaria cases.
#
# 3. **Model Development**
#    - Implement a **supervised learning** model (e.g., Decision Tree, Random Forest) using Python and Scikit-learn.
#
# 4. **Model Evaluation**
#    - Assess model performance using metrics such as **accuracy**, **precision**, **recall**, and **F1-score**.
#
# 5. **Visualization & Interpretation**
#    - Generate graphs and charts to visualize prediction outcomes and feature importance.
#
# 6. **Ethical Review**
#    - Analyze the impact of data bias, model fairness, and how the solution contributes to equitable and sustainable healthcare delivery.
#
# ---
#
# > “AI can be the bridge between innovation and sustainability.” — UN Tech Envoy
#
# ---
#
# ## 📎 Deliverables
# - ✅ GitHub Repository with:
#   - Jupyter Notebook / Python script (.py)
#   - README file with project overview, screenshots, and setup instructions
#
# - 📝 Article explaining:
#   - The SDG problem addressed
#   - The machine learning approach used
#   - Project outcomes and ethical reflections
#
# - 📊 Pitch Deck:
#   - A 5-minute slide deck explaining the solution and its real-world impact
#
# ---
#
# ## 📚 Tools & Technologies Used
# - **Python**
# - **Pandas, NumPy, Matplotlib, Scikit-learn**
# - **Jupyter Notebook / Google Colab**
# - **Open-source dataset from Kaggle or WHO**
#
# ---
#
# ## 📈 Potential Impact
# By predicting malaria outbreaks with machine learning, health authorities can:
# - Allocate medical supplies more efficiently
# - Initiate early awareness campaigns
# - Prevent deaths and reduce the disease burden in vulnerable communities
#
# ---

# %% [markdown]
# 🔹 **2. LOAD AND PREPARE YOUR DATA**

# %% [markdown]
# 📦 Import Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# 📦loading and reading the csv file

# %%
# Load your dataset
df = pd.read_csv('DatasetAfricaMalaria.csv')

# %% [markdown]
# **(a) Dataset Overview**

# %% [markdown]
# understanding the structure of the data

# %%
print(df.shape)
# Out:
# (594, 27)

# %%
df.columns
# Out:
# Index(['Country Name', 'Year', 'Country Code',
#        'Incidence of malaria (per 1,000 population at risk)',
#        'Malaria cases reported',
#        'Use of insecticide-treated bed nets (% of under-5 population)',
#        'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#        'People using safely managed drinking water services (% of population)',
#        'People using safely managed drinking water services, rural (% of rural population)',
#        'People using safely managed drinking water services, urban (% of urban population)',
#        'People using safely managed sanitation services (% of population)',
#        'People using safely managed sanitation services, rural (% of rural population)',
#        'People using safely managed sanitation services, urban  (% of urban population)',
# ...

# %%
df.dtypes
# Out:
# Country Name                                                                                object
# Year                                                                                         int64
# Country Code                                                                                object
# Incidence of malaria (per 1,000 population at risk)                                        float64
# Malaria cases reported                                                                     float64
# Use of insecticide-treated bed nets (% of under-5 population)                              float64
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    float64
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      float64
# People using safely managed drinking water services (% of population)                      float64
# ...

# %%
df.head()
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# ...

# %%
df.tail()
# Out:
#     Country Name  Year Country Code  \
# 589         Togo  2017          TGO
# 590      Tunisia  2017          TUN
# 591       Uganda  2017          UGA
# 592       Zambia  2017          ZMB
# 593     Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 589                                             278.20
# 590                                                NaN
# 591                                             336.76
# 592                                             160.05
# 593                                             108.55
#
#      Malaria cases reported  \
# 589               1755577.0
# 590                     NaN
# 591              11667831.0
# 592               5505639.0
# 593                467508.0
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# 589                                               69.7
# 590                                                NaN
# ...

# %% [markdown]
# checking the data quality

# %%
#summary statistics
df.describe()
# Out:
#               Year  Incidence of malaria (per 1,000 population at risk)  \
# count   594.000000                                         550.000000
# mean   2012.000000                                         190.087491
# std       3.164943                                         163.054527
# min    2007.000000                                           0.000000
# 25%    2009.000000                                          30.857500
# 50%    2012.000000                                         174.775000
# 75%    2015.000000                                         347.637500
# max    2017.000000                                         585.540000
#
#        Malaria cases reported  \
# count            5.500000e+02
# mean             1.068330e+06
# std              2.192802e+06
# min              0.000000e+00
# 25%              2.211750e+03
# 50%              1.130260e+05
# 75%              1.154808e+06
# max              1.682113e+07
#
# ...

# %%
#checking missing values
df.isnull().sum().sort_values(ascending= False)
# Out:
# People using safely managed drinking water services, rural (% of rural population)         506
# People using safely managed drinking water services (% of population)                      495
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      488
# People using safely managed sanitation services, rural (% of rural population)             484
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    472
# People using safely managed sanitation services, urban  (% of urban population)            462
# People using safely managed sanitation services (% of population)                          462
# Use of insecticide-treated bed nets (% of under-5 population)                              462
# People using safely managed drinking water services, urban (% of urban population)         418
# Malaria cases reported                                                                      44
# ...

# %%
#Check for Duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 🧹 **(b) Clean and Filter the Data:**

# %%
# Columns to keep
columns_to_keep = [
    'Country Name',
    'Year',
    'Incidence of malaria (per 1,000 population at risk)',  # 🎯 Target
    'Malaria cases reported',
    'Use of insecticide-treated bed nets (% of under-5 population)',
    'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
    'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
    'People using safely managed drinking water services (% of population)',  # Optional
    'People using safely managed sanitation services (% of population)'       # Optional
]


# Keep only the selected columns
df_filtered = df[columns_to_keep]

# %%
# Display the first few rows
print(df_filtered.head())
# Out:
#    Country Name  Year  Incidence of malaria (per 1,000 population at risk)  \
# 0       Algeria  2007                                               0.01
# 1        Angola  2007                                             286.72
# 2         Benin  2007                                             480.24
# 3      Botswana  2007                                               1.03
# 4  Burkina Faso  2007                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
# Filter for East African countries
east_africa_df = df_filtered[df_filtered['Country Name'].isin(['Kenya', 'Uganda', 'Tanzania'])]

# %%
# Display the first few rows
print(east_africa_df.shape)
# Out:
# (33, 9)

# %%
#checking missing values
east_africa_df.isnull().sum().sort_values(ascending= False)
# Out:
# People using safely managed drinking water services (% of population)                      22
# People using safely managed sanitation services (% of population)                          22
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    21
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      21
# Use of insecticide-treated bed nets (% of under-5 population)                              20
# Country Name                                                                                0
# Year                                                                                        0
# Incidence of malaria (per 1,000 population at risk)                                         0
# Malaria cases reported                                                                      0
# dtype: int64

# %%
print(east_africa_df)
# Out:
#     Country Name  Year  Incidence of malaria (per 1,000 population at risk)  \
# 25         Kenya  2007                                              78.02
# 48      Tanzania  2007                                             184.53
# 51        Uganda  2007                                             377.94
# 79         Kenya  2008                                              67.68
# 102     Tanzania  2008                                             171.00
# 105       Uganda  2008                                             410.46
# 133        Kenya  2009                                              67.94
# 156     Tanzania  2009                                             157.11
# 159       Uganda  2009                                             433.79
# 187        Kenya  2010                                              67.71
# 210     Tanzania  2010                                             145.46
# 213       Uganda  2010                                             417.35
# ...

# %%
#handling missing values
east_africa_df = east_africa_df.fillna(0)

# %%
#checking missing values
east_africa_df.isnull().sum().sort_values(ascending= False)
# Out:
# Country Name                                                                               0
# Year                                                                                       0
# Incidence of malaria (per 1,000 population at risk)                                        0
# Malaria cases reported                                                                     0
# Use of insecticide-treated bed nets (% of under-5 population)                              0
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    0
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      0
# People using safely managed drinking water services (% of population)                      0
# People using safely managed sanitation services (% of population)                          0
# dtype: int64

# %% [markdown]
# **checking outliers using Boxplot**

# %%
# Set plot style
sns.set(style="whitegrid")

# Plot boxplots for all numeric columns
plt.figure(figsize=(15, 8))
sns.boxplot(data=east_africa_df)
plt.xticks(rotation=45)
plt.title("Boxplots of Numeric Features (Malaria Dataset)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Code to Save Cleaned Data to CSV

# %%
# Save to CSV
east_africa_df.to_csv("malaria_cleaned_east_africa.csv", index=False)

# %% [markdown]
# 🔹 3. **Exploratory Data Analysis (EDA)**
# Use plots to understand trends and correlations:

# %% [markdown]
# ✅ Step 1: Line Plot — Trends Over Time
#
# To analyze how malaria incidence has changed from 2007 to 2017:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=east_africa_df, x='Year', y='Incidence of malaria (per 1,000 population at risk)', hue='Country Name', marker='o')
plt.title('Malaria Incidence Over Time (2007–2017)')
plt.ylabel('Incidence per 1,000 at Risk')
plt.xlabel('Year')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Step 2: Pair Plot — Bivariate Relationships
#
# This helps you explore pairwise relationships and spot any clusters or country-based differences.

# %%
features = [
    'Incidence of malaria (per 1,000 population at risk)',
    'Malaria cases reported',
    'Use of insecticide-treated bed nets (% of under-5 population)',
    'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
    'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)'
]

sns.pairplot(east_africa_df[features + ['Country Name']], hue='Country Name')
plt.suptitle('Pairwise Relationships Between Malaria Variables by Country', y=1.02)
plt.show()
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ✅ Step 3: Heatmap — Correlation Matrix
#
# To see how features correlate with malaria incidence

# %%
# Select only numerical columns
numeric_df = east_africa_df.select_dtypes(include='number')

# Set a much larger figure size
plt.figure(figsize=(15, 12))

# Create the heatmap with better visuals
sns.heatmap(
    numeric_df.corr(), 
    annot=True, 
    cmap='coolwarm', 
    fmt=".2f", 
    linewidths=0.5, 
    annot_kws={"size": 10}
)

plt.title('Correlation Heatmap of Numerical Features', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary Assumption:**
#
# "The factors driving malaria incidence are similar across Kenya, Uganda, and Tanzania, and a single model can learn this relationship while adjusting for country-level differences through encoded variables."

# %% [markdown]
# 🔹 4. **Feature Engineering**
#
# 🎯 Objective:
# Prepare your dataset so that machine learning models can understand and learn from it effectively.

# %% [markdown]
# ✅ Step 1: Define Features and Target

# %%
features = [
    'Use of insecticide-treated bed nets (% of under-5 population)',
    'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
    'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
    'People using safely managed drinking water services (% of population)',
    'People using safely managed sanitation services (% of population)',
    'Malaria cases reported',
    'Year'
]

target = 'Incidence of malaria (per 1,000 population at risk)'

# %% [markdown]
# ✅ Step 2: Encode Country Name

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
east_africa_df['Country_Code'] = encoder.fit_transform(east_africa_df['Country Name'])

# Add Country_Code to features
features.append('Country_Code')

# %% [markdown]
# ✅ Step 3: Scale Features

# %%
from sklearn.preprocessing import StandardScaler

X = df[features]
y = df[target]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 🔹 5. **TRAIN/TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=100
)

# %%
print("Training set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Training set size: (26, 8)
# Test set size: (7, 8)

# %% [markdown]
# 🔹 6. **MODEL BUILDING**

# %% [markdown]
# START WITH SIMPLE MODELS, THEN TUNE AND COMPARE

# %% [markdown]
# 📘 (i) **LINEAR REGRESSION:**

# %% [markdown]
# ✅ Step 1:Train the Model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression ()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ✅ Step 2:Applying the model to make Prediction

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)
print(y_lr_train_pred)
print(y_lr_test_pred)
# Out:
# [ 68.3029326   71.65455645  57.20230556  91.03139167 111.84885394
#   74.15711528 340.41718394 211.21083746 302.21379755 324.72028754
#  323.8359787  103.75070591 331.31477232 115.79220135  93.3022812
#   57.32765919 369.64749545 310.50224212 157.94625367 127.18255852
#   70.53159625 306.92433593 188.18719551  88.56026124  66.72673799
#  369.10846267]
# [163.83746607 311.60024188 226.70997483  55.06644761 359.17841073
#  132.8760884   51.55306742]

# %% [markdown]
# ✅ Step 3: Evaluate Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train,y_lr_train_pred)
lr_train_r2  = r2_score(y_train,y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test,y_lr_test_pred)
lr_test_r2 = r2_score(y_test,y_lr_test_pred)

# %%
import pandas as pd

# Create the result DataFrame correctly
lr_results = pd.DataFrame([['LinearRegression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]],
                          columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'])

# Display the result
print(lr_results)
# Out:
#              Method  Training MSE  Training R2    Test MSE   Test R2
# 0  LinearRegression   1494.369685     0.898252  923.925782  0.935022

# %% [markdown]
# 🌳 (ii) **RANDOM FOREST:**

# %% [markdown]
# ✅ Step 1:Train a Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the model
rf = RandomForestRegressor(max_depth=2, random_state =100)

# Train the model
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ✅ Step 2:Applying the model to make Prediction

# %%
# Predictions using Random Forest
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# View predictions
print("Random Forest - Training Predictions:")
print(y_rf_train_pred)

print("\nRandom Forest - Test Predictions:")
print(y_rf_test_pred)
# Out:
# Random Forest - Training Predictions:
# [ 73.66847955  73.53152062  73.53152062  73.53152062 131.65097669
#   73.53152062 385.302006   132.97469419 274.91417448 268.50308353
#  340.64866203 132.97469419 387.35522505 131.65097669 132.97469419
#   73.66847955 387.662086   290.00360722 132.97469419 132.97469419
#   73.53152062 275.14052984 131.65097669  73.53152062  73.53152062
#  387.71142505]
#
# Random Forest - Test Predictions:
# [131.65097669 268.50308353 131.65097669  73.66847955 387.662086
#  131.65097669  73.66847955]

# %% [markdown]
# ✅ Step 3: Evaluate Model Performance

# %% [markdown]
# 📘 Random Forest Performance Evaluation

# %%
# Evaluate Random Forest performance
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
import pandas as pd

# Create the result DataFrame for Random Forest
rf_results = pd.DataFrame([['RandomForest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]],
                          columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'])

# Display the result
print(rf_results)
# Out:
#          Method  Training MSE  Training R2    Test MSE   Test R2
# 0  RandomForest    605.639949     0.958764  717.761968  0.949521

# %% [markdown]
# (iii) **Decision Tree for Malaria Incidence Prediction**

# %% [markdown]
# ✅ Step 1:Train a  Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
# Initialize the model
dt = DecisionTreeRegressor(random_state=42)
# Train the model
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ✅ Step 2:Applying the model to make Prediction

# %%
y_dt_train_pred = dt.predict(X_train)
y_dt_test_pred = dt.predict(X_test)

# %% [markdown]
# ✅ Step 3: Evaluate Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

dt_train_mse = mean_squared_error(y_train, y_dt_train_pred)
dt_train_r2 = r2_score(y_train, y_dt_train_pred)

dt_test_mse = mean_squared_error(y_test, y_dt_test_pred)
dt_test_r2 = r2_score(y_test, y_dt_test_pred)

# %%
import pandas as pd

dt_results = pd.DataFrame([['DecisionTree', dt_train_mse, dt_train_r2, dt_test_mse, dt_test_r2]],
                          columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'])

print(dt_results)
# Out:
#          Method  Training MSE  Training R2    Test MSE   Test R2
# 0  DecisionTree           0.0          1.0  937.212586  0.934088

# %% [markdown]
# **MODEL COMPARISON**

# %% [markdown]
# Let's summarize and compare the three models — Linear Regression, Random Forest, and Decision Tree — in a clean table based on the evaluation metrics:

# %%
import pandas as pd

# Combine results
comparison_df = pd.DataFrame([
    ['Linear Regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2],
    ['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2],
    ['Decision Tree', dt_train_mse, dt_train_r2, dt_test_mse, dt_test_r2]
], columns=['Model', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'])

# Display
print(comparison_df)
# Out:
#                Model  Training MSE  Training R2    Test MSE   Test R2
# 0  Linear Regression   1494.369685     0.898252  923.925782  0.935022
# 1      Random Forest    605.639949     0.958764  717.761968  0.949521
# 2      Decision Tree      0.000000     1.000000  937.212586  0.934088

# %% [markdown]
# 📊 **What to Look for in Model Evaluation**
#
# Lower MSE
#
# ✅ Mean Squared Error (MSE) measures how close the predicted values are to the actual values.
#
# 🔽 Lower values indicate better model accuracy.
#
# Higher R²
#
# ✅ R-squared (R²) shows how much of the variation in the target variable is explained by the model.
#
# 🔼 Higher values (closer to 1) indicate the model explains more variance.
#
# Train vs Test Scores
#
# ⚠️ If the test scores are much worse than the train scores, it may indicate overfitting — the model learned the training data too well and performs poorly on new data.
#
# Look for a balance between training and test performance.

# %% [markdown]
# 📊 **Model Comparison Bar Chart (MSE and R²)**

# %%
plt.figure(figsize=(14, 6))

# Test MSE Comparison
plt.subplot(1, 2, 1)
sns.barplot(data=comparison_df, x='Model', y='Test MSE', palette='Blues_d')
plt.title('Model Comparison: Test MSE')
plt.ylabel('Mean Squared Error')

# Test R2 Comparison (updated column name)
plt.subplot(1, 2, 2)
sns.barplot(data=comparison_df, x='Model', y='Test R2', palette='Greens_d')  # e.g., if column is 'R2'
plt.title('Model Comparison: Test R²')
plt.ylabel('R-squared Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# 📈 **Data Visualization of Prediction Results**

# %% [markdown]
# **Plot True vs Predicted Values (Example for All Models)**

# %%
plt.figure(figsize=(12, 6))

# Linear Regression
plt.subplot(1, 3, 1)
sns.scatterplot(x=y_test, y=y_lr_test_pred, color='blue')
plt.plot(y_test, y_test, color='black', linestyle='--')
plt.title('Linear Regression')
plt.xlabel('Actual')
plt.ylabel('Predicted')

# Random Forest
plt.subplot(1, 3, 2)
sns.scatterplot(x=y_test, y=y_rf_test_pred, color='green')
plt.plot(y_test, y_test, color='black', linestyle='--')
plt.title('Random Forest')
plt.xlabel('Actual')
plt.ylabel('Predicted')

# Decision Tree
plt.subplot(1, 3, 3)
sns.scatterplot(x=y_test, y=y_dt_test_pred, color='orange')
plt.plot(y_test, y_test, color='black', linestyle='--')
plt.title('Decision Tree')
plt.xlabel('Actual')
plt.ylabel('Predicted')

plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ **What to Look For:**
#
# Points closer to the diagonal line (perfect prediction line) mean better accuracy.
#
# Scatter tightly packed around the line = strong prediction.
#
# Large deviation from the line indicates prediction error.

# %% [markdown]
# **Visualize Predictions Over Time**

# %%
# Step 1: Extract the original 'Year' column from the full df
X_unscaled = east_africa_df[['Year']]

# Step 2: Do the same train-test split as before
from sklearn.model_selection import train_test_split

_, X_test_unscaled, _, _ = train_test_split(X_unscaled, y, test_size=0.2, random_state=42)

# Step 3: Use it in your prediction DataFrame
pred_df = pd.DataFrame({
    'Year': X_test_unscaled['Year'].values,
    'Actual': y_test.values,
    'Predicted': y_rf_test_pred  # or y_lr_test_pred, y_dt_test_pred depending on the model
})

# %%
import matplotlib.pyplot as plt

# Sort by Year (for clean line plot)
pred_df = pred_df.sort_values(by='Year')

# Plot actual vs predicted over time
plt.figure(figsize=(10, 6))
plt.plot(pred_df['Year'], pred_df['Actual'], label='Actual', marker='o')
plt.plot(pred_df['Year'], pred_df['Predicted'], label='Predicted', marker='x')
plt.title('Malaria Incidence: Actual vs Predicted Over Time')
plt.xlabel('Year')
plt.ylabel('Incidence (per 1,000 at risk)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#  **Visualization for All Three Models**

# %%
# Step 1: Recreate the original 'Year' split
X_unscaled = east_africa_df[['Year']]
_, X_test_unscaled, _, _ = train_test_split(X_unscaled, y, test_size=0.2, random_state=42)

# Step 2: Build a combined DataFrame with predictions from all models
comparison_df = pd.DataFrame({
    'Year': X_test_unscaled['Year'].values,
    'Actual': y_test.values,
    'Linear Regression': y_lr_test_pred,
    'Random Forest': y_rf_test_pred,
    'Decision Tree': y_dt_test_pred
})

# Step 3: Sort by year for smooth lines
comparison_df = comparison_df.sort_values(by='Year')

# Step 4: Plot actual vs. predicted for each model
plt.figure(figsize=(12, 6))
plt.plot(comparison_df['Year'], comparison_df['Actual'], label='Actual', marker='o', linewidth=2)
plt.plot(comparison_df['Year'], comparison_df['Linear Regression'], label='Linear Regression', marker='x')
plt.plot(comparison_df['Year'], comparison_df['Random Forest'], label='Random Forest', marker='s')
plt.plot(comparison_df['Year'], comparison_df['Decision Tree'], label='Decision Tree', marker='^')

plt.title('📈 Malaria Incidence Prediction Over Time (All Models)')
plt.xlabel('Year')
plt.ylabel('Incidence (per 1,000 at risk)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_190/694305471.py:29: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   plt.tight_layout()
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 🧠 How the Line Plot Achieves Insightful Evaluation
#
# ### 1. Tracking Closest to Actual (Model Accuracy)
# **What to look for:**
#
# The model line (e.g., “Random Forest”) that stays **closest** to the “Actual” line (ground truth) across all years.
#
# **What it means:**
#
# - If a model’s prediction line nearly overlaps the actual values, it’s **very accurate**.
# - **Example:** If Random Forest’s line hugs the actual line across the timeline, it's likely the **best model**.
#
# ---
#
# ### 2. Spotting Over- or Under-Prediction
# **What to look for:**
#
# - **Over-prediction** → model's line is consistently **above** the actual line.
# - **Under-prediction** → model's line is consistently **below** the actual line.
#
# **What it means:**
#
# - A pattern of over- or under-predicting reveals **bias** in the model.
# - **Example:** If the Linear Regression model keeps **overestimating** in early years, it might not be capturing some **temporal patterns**.
#
# ---
#
# ### 3. Evaluating Trend Matching (Pattern Fit)
# **What to look for:**
#
# Does the shape of the model’s line follow the same **ups and downs** as the actual line?
#
# **What it means:**
#
# - A model that correctly predicts **trend directions** (e.g., increasing/decreasing years) shows it understands the **temporal structure**.
# - Even if exact numbers are a bit off, **capturing trends** is important in forecasting.

# %% [markdown]
# ✅ Post-Modeling:

# %% [markdown]
# 1. **Save Trained Model**

# %%
import joblib

#  Save your Random Forest model
joblib.dump(rf, 'random_forest_model.pkl')

# Save Linear Regression model
joblib.dump(lr, 'linear_regression_model.pkl')

# Save Decision Tree model
joblib.dump(dt, 'decision_tree_model.pkl')
# Out:
# ['decision_tree_model.pkl']
